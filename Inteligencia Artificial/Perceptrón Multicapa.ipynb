# %% [markdown]
# # Classification of musical rhythms of ecuador using Deep Learning
# ### 1 Data Exploration and Visualisation

# %%
# Load imports

import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
import pandas as pd
metadata = pd.read_csv('audios/dataset.csv',delimiter=';',encoding = 'unicode_escape')
metadata.head()
# Out:
#    Id Sonido    Clase  Clase_Id
# 0   1  1.wav  Pasillo         1
# 1   2  2.wav  Pasillo         1
# 2   3  3.wav  Pasillo         1
# 3   4  4.wav  Pasillo         1
# 4   5  5.wav  Pasillo         1

# %%
print(metadata.Clase.value_counts())
# Out:
# Capishca      60
# Tonada        60
# Danzante      60
# Pasillo       60
# Alza          60
# SanJuanito    60
# Yumbo         60
# Albazo        60
# Pasacalle     60
# Name: Clase, dtype: int64

# %%
import struct

class WavFileHelper():
    
    def read_file_properties(self, filename):

        wave_file = open(filename,"rb")
        
        riff = wave_file.read(12)
        fmt = wave_file.read(36)
        
        num_channels_string = fmt[10:12]
        num_channels = struct.unpack('<H', num_channels_string)[0]

        sample_rate_string = fmt[12:16]
        sample_rate = struct.unpack("<I",sample_rate_string)[0]
        
        bit_depth_string = fmt[22:24]
        bit_depth = struct.unpack("<H",bit_depth_string)[0]

        return (num_channels, sample_rate, bit_depth)

# %%
# Load various imports 
import pandas as pd
import os
import librosa
import librosa.display

from wavfilehelper import WavFileHelper
wavfilehelper = WavFileHelper()
audiodata = []
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath('audios/'),str(row["Sonido"]))
    data = wavfilehelper.read_file_properties(file_name)
    audiodata.append(data)

# Convert into a Panda dataframe
audiodf = pd.DataFrame(audiodata, columns=['num_channels','sample_rate','bit_depth'])

# %%
# num of channels 

print(audiodf.num_channels.value_counts(normalize=True))
# Out:
# 2    0.97037
# 1    0.02963
# Name: num_channels, dtype: float64

# %%
# sample rates 

print(audiodf.sample_rate.value_counts(normalize=True))
# Out:
# 48000    0.998148
# 44100    0.001852
# Name: sample_rate, dtype: float64

# %%
# bit depth

print(audiodf.bit_depth.value_counts(normalize=True))
# Out:
# 16    1.0
# Name: bit_depth, dtype: float64

# %% [markdown]
# ### 2 Data Preprocessing

# %%
import librosa 
from scipy.io import wavfile as wav
import numpy as np

filename = 'audios/38.wav' 

librosa_audio, librosa_sample_rate = librosa.load(filename,mono=True) 
scipy_sample_rate, scipy_audio = wav.read(filename) 

print('Original sample rate:', scipy_sample_rate) 
print('Librosa sample rate:', librosa_sample_rate)
# Out:
# Original sample rate: 48000
# Librosa sample rate: 22050

# %%
def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 

metadata = pd.read_csv('audios/dataset.csv',delimiter=';',encoding = 'unicode_escape')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    
    
    file_name = os.path.join(os.path.abspath('audios/'),str(row["Sonido"]))
    class_label = row["Clase"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# Finished feature extraction from  540  files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))

# %%
# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
### store the preprocessed data for use in the next notebook

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 
# %store yy 
# %store le
# Out:
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)

# %% [markdown]
# ### 3 Model Training and Evaluation

# %%
import numpy as np
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten
#from keras.models import Sequential
#from keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.python.keras.layers import Convolution2D, MaxPooling2D
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.utils import np_utils
from sklearn import metrics 





num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()

model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 256)               10496
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# activation_13 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 9)                 2313
# _________________________________________________________________
# activation_14 (Activation)   (None, 9)                 0
# =================================================================
# Total params: 78,601
# Trainable params: 78,601
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 8.3333%

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint 
from datetime import datetime 
num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_mlp.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
#  1/14 [=>............................] - ETA: 0s - loss: 36.0215 - accuracy: 0.1562
# Epoch 00001: val_loss improved from inf to 8.13176, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 1s 54ms/step - loss: 26.5555 - accuracy: 0.1366 - val_loss: 8.1318 - val_accuracy: 0.2222
# Epoch 2/100
# 13/14 [==========================>...] - ETA: 0s - loss: 15.3519 - accuracy: 0.1731
# Epoch 00002: val_loss improved from 8.13176 to 4.19648, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 17ms/step - loss: 15.2868 - accuracy: 0.1782 - val_loss: 4.1965 - val_accuracy: 0.2593
# Epoch 3/100
#  1/14 [=>............................] - ETA: 0s - loss: 13.4110 - accuracy: 0.1875
# Epoch 00003: val_loss improved from 4.19648 to 2.12964, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 19ms/step - loss: 10.3021 - accuracy: 0.2523 - val_loss: 2.1296 - val_accuracy: 0.2685
# Epoch 4/100
#  8/14 [================>.............] - ETA: 0s - loss: 6.9337 - accuracy: 0.2500
# Epoch 00004: val_loss improved from 2.12964 to 1.75211, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 24ms/step - loss: 6.9175 - accuracy: 0.2523 - val_loss: 1.7521 - val_accuracy: 0.3611
# Epoch 5/100
#  1/14 [=>............................] - ETA: 0s - loss: 6.1006 - accuracy: 0.2500
# Epoch 00005: val_loss improved from 1.75211 to 1.68142, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 20ms/step - loss: 5.4001 - accuracy: 0.2523 - val_loss: 1.6814 - val_accuracy: 0.4352
# Epoch 6/100
#  1/14 [=>............................] - ETA: 0s - loss: 4.6491 - accuracy: 0.1562
# Epoch 00006: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 10ms/step - loss: 4.2865 - accuracy: 0.2569 - val_loss: 1.7442 - val_accuracy: 0.4630
# Epoch 7/100
#  1/14 [=>............................] - ETA: 0s - loss: 3.6520 - accuracy: 0.3125
# Epoch 00007: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 3.2778 - accuracy: 0.2986 - val_loss: 1.7940 - val_accuracy: 0.4259
# Epoch 8/100
#  1/14 [=>............................] - ETA: 0s - loss: 3.1629 - accuracy: 0.3125
# Epoch 00008: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 2.7386 - accuracy: 0.3449 - val_loss: 1.8764 - val_accuracy: 0.3611
# Epoch 9/100
#  1/14 [=>............................] - ETA: 0s - loss: 2.2950 - accuracy: 0.2500
# Epoch 00009: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 10ms/step - loss: 2.5513 - accuracy: 0.3125 - val_loss: 1.8935 - val_accuracy: 0.4167
# Epoch 10/100
# 10/14 [====================>.........] - ETA: 0s - loss: 2.3290 - accuracy: 0.3531
# Epoch 00010: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 12ms/step - loss: 2.3347 - accuracy: 0.3519 - val_loss: 1.8687 - val_accuracy: 0.3889
# Epoch 11/100
#  1/14 [=>............................] - ETA: 0s - loss: 2.1498 - accuracy: 0.3438
# Epoch 00011: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 8ms/step - loss: 2.1810 - accuracy: 0.3194 - val_loss: 1.8420 - val_accuracy: 0.4444
# Epoch 12/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.9514 - accuracy: 0.4062
# Epoch 00012: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 1.9665 - accuracy: 0.3634 - val_loss: 1.8305 - val_accuracy: 0.4444
# Epoch 13/100
#  1/14 [=>............................] - ETA: 0s - loss: 2.0359 - accuracy: 0.4688
# Epoch 00013: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 2.0356 - accuracy: 0.3472 - val_loss: 1.7966 - val_accuracy: 0.4815
# Epoch 14/100
#  1/14 [=>............................] - ETA: 0s - loss: 2.0093 - accuracy: 0.5625
# Epoch 00014: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 1.8775 - accuracy: 0.4097 - val_loss: 1.7740 - val_accuracy: 0.4352
# Epoch 15/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.8479 - accuracy: 0.4375
# Epoch 00015: val_loss did not improve from 1.68142
# 14/14 [==============================] - 0s 9ms/step - loss: 1.7232 - accuracy: 0.4259 - val_loss: 1.7168 - val_accuracy: 0.5278
# Epoch 16/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.5685 - accuracy: 0.4688
# Epoch 00016: val_loss improved from 1.68142 to 1.65901, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 14ms/step - loss: 1.7389 - accuracy: 0.4282 - val_loss: 1.6590 - val_accuracy: 0.5556
# Epoch 17/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.8651 - accuracy: 0.3750
# Epoch 00017: val_loss improved from 1.65901 to 1.61146, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 11ms/step - loss: 1.6923 - accuracy: 0.4329 - val_loss: 1.6115 - val_accuracy: 0.5370
# Epoch 18/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.6721 - accuracy: 0.3750
# Epoch 00018: val_loss improved from 1.61146 to 1.52577, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 8ms/step - loss: 1.5615 - accuracy: 0.4537 - val_loss: 1.5258 - val_accuracy: 0.5833
# Epoch 19/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.3714 - accuracy: 0.5625
# Epoch 00019: val_loss improved from 1.52577 to 1.45341, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 15ms/step - loss: 1.5397 - accuracy: 0.4699 - val_loss: 1.4534 - val_accuracy: 0.6481
# Epoch 20/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.3764 - accuracy: 0.6562
# Epoch 00020: val_loss improved from 1.45341 to 1.37234, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 8ms/step - loss: 1.4934 - accuracy: 0.4792 - val_loss: 1.3723 - val_accuracy: 0.7407
# Epoch 21/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.4478 - accuracy: 0.4688
# Epoch 00021: val_loss improved from 1.37234 to 1.33091, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 1.4044 - accuracy: 0.4815 - val_loss: 1.3309 - val_accuracy: 0.7500
# Epoch 22/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.6759 - accuracy: 0.3750
# Epoch 00022: val_loss improved from 1.33091 to 1.20598, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 20ms/step - loss: 1.3336 - accuracy: 0.5324 - val_loss: 1.2060 - val_accuracy: 0.7407
# Epoch 23/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.5286 - accuracy: 0.4375
# Epoch 00023: val_loss improved from 1.20598 to 1.15753, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3911 - accuracy: 0.5255 - val_loss: 1.1575 - val_accuracy: 0.7593
# Epoch 24/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.6932 - accuracy: 0.5625
# Epoch 00024: val_loss improved from 1.15753 to 1.12752, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 13ms/step - loss: 1.1697 - accuracy: 0.6157 - val_loss: 1.1275 - val_accuracy: 0.7407
# Epoch 25/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.7531 - accuracy: 0.4062
# Epoch 00025: val_loss improved from 1.12752 to 1.03936, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2068 - accuracy: 0.5625 - val_loss: 1.0394 - val_accuracy: 0.8148
# Epoch 26/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.0374 - accuracy: 0.6875
# Epoch 00026: val_loss improved from 1.03936 to 0.95766, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 18ms/step - loss: 1.1850 - accuracy: 0.6088 - val_loss: 0.9577 - val_accuracy: 0.8333
# Epoch 27/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.7505 - accuracy: 0.6875
# Epoch 00027: val_loss improved from 0.95766 to 0.90075, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1058 - accuracy: 0.6227 - val_loss: 0.9008 - val_accuracy: 0.8889
# Epoch 28/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.5803 - accuracy: 0.4375
# Epoch 00028: val_loss improved from 0.90075 to 0.86008, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 1.0982 - accuracy: 0.6273 - val_loss: 0.8601 - val_accuracy: 0.8889
# Epoch 29/100
#  1/14 [=>............................] - ETA: 0s - loss: 1.0540 - accuracy: 0.6250
# Epoch 00029: val_loss improved from 0.86008 to 0.79420, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 12ms/step - loss: 0.9216 - accuracy: 0.6944 - val_loss: 0.7942 - val_accuracy: 0.8889
# Epoch 30/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.9302 - accuracy: 0.6875
# Epoch 00030: val_loss improved from 0.79420 to 0.68122, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 0.8948 - accuracy: 0.6829 - val_loss: 0.6812 - val_accuracy: 0.8796
# Epoch 31/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.9275 - accuracy: 0.6755
# Epoch 00031: val_loss improved from 0.68122 to 0.63575, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 18ms/step - loss: 0.9282 - accuracy: 0.6713 - val_loss: 0.6357 - val_accuracy: 0.9167
# Epoch 32/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.7672 - accuracy: 0.7188
# Epoch 00032: val_loss improved from 0.63575 to 0.59390, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.9162 - accuracy: 0.6806 - val_loss: 0.5939 - val_accuracy: 0.8981
# Epoch 33/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.9753 - accuracy: 0.7188
# Epoch 00033: val_loss improved from 0.59390 to 0.51365, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.8323 - accuracy: 0.6921 - val_loss: 0.5136 - val_accuracy: 0.8981
# Epoch 34/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.8044 - accuracy: 0.7188
# Epoch 00034: val_loss improved from 0.51365 to 0.45499, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.7660 - accuracy: 0.7338 - val_loss: 0.4550 - val_accuracy: 0.9352
# Epoch 35/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.7609 - accuracy: 0.6562
# Epoch 00035: val_loss did not improve from 0.45499
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7994 - accuracy: 0.7245 - val_loss: 0.4563 - val_accuracy: 0.9167
# Epoch 36/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4859 - accuracy: 0.8125
# Epoch 00036: val_loss improved from 0.45499 to 0.45043, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.7427 - accuracy: 0.7384 - val_loss: 0.4504 - val_accuracy: 0.9259
# Epoch 37/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4911 - accuracy: 0.8125
# Epoch 00037: val_loss improved from 0.45043 to 0.42850, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7562 - accuracy: 0.7500 - val_loss: 0.4285 - val_accuracy: 0.9167
# Epoch 38/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4416 - accuracy: 0.7812
# Epoch 00038: val_loss improved from 0.42850 to 0.36239, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 1s 40ms/step - loss: 0.6764 - accuracy: 0.7523 - val_loss: 0.3624 - val_accuracy: 0.9537
# Epoch 39/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.8070 - accuracy: 0.6562
# Epoch 00039: val_loss improved from 0.36239 to 0.33638, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6349 - accuracy: 0.7870 - val_loss: 0.3364 - val_accuracy: 0.9537
# Epoch 40/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.6622 - accuracy: 0.8125
# Epoch 00040: val_loss improved from 0.33638 to 0.32971, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5951 - accuracy: 0.7917 - val_loss: 0.3297 - val_accuracy: 0.9537
# Epoch 41/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.6112 - accuracy: 0.7812
# Epoch 00041: val_loss improved from 0.32971 to 0.30298, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5359 - accuracy: 0.8194 - val_loss: 0.3030 - val_accuracy: 0.9630
# Epoch 42/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.7974 - accuracy: 0.6875
# Epoch 00042: val_loss improved from 0.30298 to 0.28283, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5781 - accuracy: 0.8056 - val_loss: 0.2828 - val_accuracy: 0.9630
# Epoch 43/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.5541 - accuracy: 0.8005
# Epoch 00043: val_loss did not improve from 0.28283
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5624 - accuracy: 0.7963 - val_loss: 0.2884 - val_accuracy: 0.9630
# Epoch 44/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.5452 - accuracy: 0.7812
# Epoch 00044: val_loss improved from 0.28283 to 0.27587, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4944 - accuracy: 0.8171 - val_loss: 0.2759 - val_accuracy: 0.9815
# Epoch 45/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4210 - accuracy: 0.8438
# Epoch 00045: val_loss improved from 0.27587 to 0.25976, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5037 - accuracy: 0.8310 - val_loss: 0.2598 - val_accuracy: 0.9722
# Epoch 46/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4902 - accuracy: 0.9062
# Epoch 00046: val_loss improved from 0.25976 to 0.24703, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4880 - accuracy: 0.8495 - val_loss: 0.2470 - val_accuracy: 0.9537
# Epoch 47/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.6030 - accuracy: 0.8125
# Epoch 00047: val_loss improved from 0.24703 to 0.23209, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4898 - accuracy: 0.8333 - val_loss: 0.2321 - val_accuracy: 0.9630
# Epoch 48/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4498 - accuracy: 0.8750
# Epoch 00048: val_loss improved from 0.23209 to 0.19810, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4517 - accuracy: 0.8519 - val_loss: 0.1981 - val_accuracy: 0.9630
# Epoch 49/100
# 12/14 [========================>.....] - ETA: 0s - loss: 0.3447 - accuracy: 0.8984
# Epoch 00049: val_loss improved from 0.19810 to 0.16673, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3622 - accuracy: 0.8889 - val_loss: 0.1667 - val_accuracy: 0.9722
# Epoch 50/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4463 - accuracy: 0.8125
# Epoch 00050: val_loss improved from 0.16673 to 0.15371, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4434 - accuracy: 0.8611 - val_loss: 0.1537 - val_accuracy: 0.9815
# Epoch 51/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4223 - accuracy: 0.9062
# Epoch 00051: val_loss did not improve from 0.15371
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.8681 - val_loss: 0.1621 - val_accuracy: 0.9815
# Epoch 52/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3021 - accuracy: 0.8750
# Epoch 00052: val_loss did not improve from 0.15371
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3293 - accuracy: 0.8796 - val_loss: 0.1607 - val_accuracy: 0.9907
# Epoch 53/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3903 - accuracy: 0.8750
# Epoch 00053: val_loss did not improve from 0.15371
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3789 - accuracy: 0.8796 - val_loss: 0.1627 - val_accuracy: 0.9815
# Epoch 54/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3308 - accuracy: 0.8750
# Epoch 00054: val_loss improved from 0.15371 to 0.13593, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.3967 - accuracy: 0.8750 - val_loss: 0.1359 - val_accuracy: 0.9815
# Epoch 55/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2657 - accuracy: 0.9062
# Epoch 00055: val_loss improved from 0.13593 to 0.13295, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2956 - accuracy: 0.9097 - val_loss: 0.1330 - val_accuracy: 0.9815
# Epoch 56/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.5140 - accuracy: 0.8438
# Epoch 00056: val_loss improved from 0.13295 to 0.12021, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3322 - accuracy: 0.9051 - val_loss: 0.1202 - val_accuracy: 0.9907
# Epoch 57/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3844 - accuracy: 0.8125
# Epoch 00057: val_loss improved from 0.12021 to 0.11398, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3036 - accuracy: 0.8866 - val_loss: 0.1140 - val_accuracy: 0.9907
# Epoch 58/100
#  6/14 [===========>..................] - ETA: 0s - loss: 0.3321 - accuracy: 0.9062
# Epoch 00058: val_loss did not improve from 0.11398
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3308 - accuracy: 0.9074 - val_loss: 0.1249 - val_accuracy: 0.9815
# Epoch 59/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2938 - accuracy: 0.9375
# Epoch 00059: val_loss did not improve from 0.11398
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3459 - accuracy: 0.8819 - val_loss: 0.1155 - val_accuracy: 0.9907
# Epoch 60/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1917 - accuracy: 0.9375
# Epoch 00060: val_loss improved from 0.11398 to 0.10646, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2920 - accuracy: 0.9167 - val_loss: 0.1065 - val_accuracy: 0.9907
# Epoch 61/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1948 - accuracy: 0.8750
# Epoch 00061: val_loss did not improve from 0.10646
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2527 - accuracy: 0.9144 - val_loss: 0.1111 - val_accuracy: 0.9907
# Epoch 62/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2872 - accuracy: 0.9375
# Epoch 00062: val_loss improved from 0.10646 to 0.08649, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 21ms/step - loss: 0.2870 - accuracy: 0.9028 - val_loss: 0.0865 - val_accuracy: 0.9815
# Epoch 63/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0886 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.08649
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2606 - accuracy: 0.9074 - val_loss: 0.0915 - val_accuracy: 0.9722
# Epoch 64/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2261 - accuracy: 0.9375
# Epoch 00064: val_loss did not improve from 0.08649
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2866 - accuracy: 0.9051 - val_loss: 0.1069 - val_accuracy: 0.9722
# Epoch 65/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1649 - accuracy: 0.9375
# Epoch 00065: val_loss did not improve from 0.08649
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3008 - accuracy: 0.9097 - val_loss: 0.1041 - val_accuracy: 0.9815
# Epoch 66/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1156 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.08649
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.9352 - val_loss: 0.0950 - val_accuracy: 0.9815
# Epoch 67/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2406 - accuracy: 0.9375
# Epoch 00067: val_loss improved from 0.08649 to 0.08603, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2945 - accuracy: 0.9120 - val_loss: 0.0860 - val_accuracy: 0.9815
# Epoch 68/100
# 11/14 [======================>.......] - ETA: 0s - loss: 0.2700 - accuracy: 0.9176
# Epoch 00068: val_loss did not improve from 0.08603
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2500 - accuracy: 0.9167 - val_loss: 0.0907 - val_accuracy: 0.9815
# Epoch 69/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1241 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.08603
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2417 - accuracy: 0.9352 - val_loss: 0.1046 - val_accuracy: 0.9815
# Epoch 70/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1835 - accuracy: 0.9062
# Epoch 00070: val_loss improved from 0.08603 to 0.07997, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 1s 97ms/step - loss: 0.2161 - accuracy: 0.9236 - val_loss: 0.0800 - val_accuracy: 0.9815
# Epoch 71/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.5938 - accuracy: 0.8125
# Epoch 00071: val_loss improved from 0.07997 to 0.06896, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 18ms/step - loss: 0.2533 - accuracy: 0.9213 - val_loss: 0.0690 - val_accuracy: 0.9815
# Epoch 72/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2862 - accuracy: 0.9688
# Epoch 00072: val_loss did not improve from 0.06896
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2477 - accuracy: 0.9236 - val_loss: 0.0773 - val_accuracy: 0.9815
# Epoch 73/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2572 - accuracy: 0.9375
# Epoch 00073: val_loss did not improve from 0.06896
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2683 - accuracy: 0.9236 - val_loss: 0.0965 - val_accuracy: 0.9630
# Epoch 74/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1378 - accuracy: 0.9688
# Epoch 00074: val_loss did not improve from 0.06896
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2184 - accuracy: 0.9375 - val_loss: 0.0889 - val_accuracy: 0.9815
# Epoch 75/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0403 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.06896
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2207 - accuracy: 0.9236 - val_loss: 0.0736 - val_accuracy: 0.9815
# Epoch 76/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2575 - accuracy: 0.9375
# Epoch 00076: val_loss did not improve from 0.06896
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 0.9468 - val_loss: 0.0726 - val_accuracy: 0.9907
# Epoch 77/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2824 - accuracy: 0.9375
# Epoch 00077: val_loss improved from 0.06896 to 0.06494, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 31ms/step - loss: 0.2357 - accuracy: 0.9282 - val_loss: 0.0649 - val_accuracy: 0.9907
# Epoch 78/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.9167
# Epoch 00078: val_loss improved from 0.06494 to 0.05762, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 17ms/step - loss: 0.2564 - accuracy: 0.9167 - val_loss: 0.0576 - val_accuracy: 0.9907
# Epoch 79/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0880 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.05762
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.9537 - val_loss: 0.0690 - val_accuracy: 0.9815
# Epoch 80/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.4052 - accuracy: 0.9062
# Epoch 00080: val_loss improved from 0.05762 to 0.05651, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2054 - accuracy: 0.9468 - val_loss: 0.0565 - val_accuracy: 0.9907
# Epoch 81/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3241 - accuracy: 0.9062
# Epoch 00081: val_loss improved from 0.05651 to 0.05206, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2009 - accuracy: 0.9398 - val_loss: 0.0521 - val_accuracy: 0.9907
# Epoch 82/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1363 - accuracy: 0.9688
# Epoch 00082: val_loss improved from 0.05206 to 0.05072, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1817 - accuracy: 0.9421 - val_loss: 0.0507 - val_accuracy: 0.9907
# Epoch 83/100
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1629 - accuracy: 0.9438
# Epoch 00083: val_loss improved from 0.05072 to 0.04758, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1555 - accuracy: 0.9468 - val_loss: 0.0476 - val_accuracy: 0.9907
# Epoch 84/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1330 - accuracy: 0.9375
# Epoch 00084: val_loss improved from 0.04758 to 0.04755, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2083 - accuracy: 0.9306 - val_loss: 0.0475 - val_accuracy: 0.9907
# Epoch 85/100
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1832 - accuracy: 0.9290
# Epoch 00085: val_loss improved from 0.04755 to 0.04406, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1689 - accuracy: 0.9329 - val_loss: 0.0441 - val_accuracy: 0.9907
# Epoch 86/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2136 - accuracy: 0.9688
# Epoch 00086: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1471 - accuracy: 0.9676 - val_loss: 0.0472 - val_accuracy: 0.9907
# Epoch 87/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1405 - accuracy: 0.9375
# Epoch 00087: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9514 - val_loss: 0.0763 - val_accuracy: 0.9722
# Epoch 88/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3686 - accuracy: 0.8750
# Epoch 00088: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1762 - accuracy: 0.9421 - val_loss: 0.0544 - val_accuracy: 0.9815
# Epoch 89/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0941 - accuracy: 0.9688
# Epoch 00089: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1578 - accuracy: 0.9468 - val_loss: 0.0569 - val_accuracy: 0.9815
# Epoch 90/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0896 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1718 - accuracy: 0.9421 - val_loss: 0.0483 - val_accuracy: 0.9907
# Epoch 91/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0669 - accuracy: 1.0000
# Epoch 00091: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1542 - accuracy: 0.9537 - val_loss: 0.0522 - val_accuracy: 0.9815
# Epoch 92/100
# 10/14 [====================>.........] - ETA: 0s - loss: 0.1549 - accuracy: 0.9625
# Epoch 00092: val_loss did not improve from 0.04406
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9514 - val_loss: 0.0477 - val_accuracy: 0.9815
# Epoch 93/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0530 - accuracy: 1.0000
# Epoch 00093: val_loss improved from 0.04406 to 0.04219, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 34ms/step - loss: 0.1575 - accuracy: 0.9444 - val_loss: 0.0422 - val_accuracy: 0.9815
# Epoch 94/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0370 - accuracy: 1.0000
# Epoch 00094: val_loss improved from 0.04219 to 0.03832, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1304 - accuracy: 0.9606 - val_loss: 0.0383 - val_accuracy: 0.9907
# Epoch 95/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0687 - accuracy: 1.0000
# Epoch 00095: val_loss improved from 0.03832 to 0.03617, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1629 - accuracy: 0.9491 - val_loss: 0.0362 - val_accuracy: 0.9907
# Epoch 96/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1014 - accuracy: 0.9688
# Epoch 00096: val_loss did not improve from 0.03617
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9722 - val_loss: 0.0368 - val_accuracy: 0.9907
# Epoch 97/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0349 - accuracy: 0.9688
# Epoch 00097: val_loss improved from 0.03617 to 0.03186, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1303 - accuracy: 0.9583 - val_loss: 0.0319 - val_accuracy: 0.9907
# Epoch 98/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0590 - accuracy: 0.9688
# Epoch 00098: val_loss did not improve from 0.03186
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0933 - accuracy: 0.9630 - val_loss: 0.0364 - val_accuracy: 0.9907
# Epoch 99/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.2603 - accuracy: 0.9688
# Epoch 00099: val_loss did not improve from 0.03186
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1196 - accuracy: 0.9699 - val_loss: 0.0339 - val_accuracy: 0.9907
# Epoch 100/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.3084 - accuracy: 0.8750
# Epoch 00100: val_loss improved from 0.03186 to 0.02741, saving model to saved_models\weights.best.basic_mlp.hdf5
# 14/14 [==============================] - 0s 28ms/step - loss: 0.1076 - accuracy: 0.9630 - val_loss: 0.0274 - val_accuracy: 0.9907
# Training completed in time:  0:00:21.532393

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9907407164573669

# %%
import librosa 
import numpy as np 

def extract_feature(file_name):
   
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None

    return np.array([mfccsscaled])

# %%
def print_prediction(file_name):
    prediction_feature = extract_feature(file_name) 

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
# Class: Pasillo
filename = 'audio_modelo/Pasillo.wav'
print_prediction(filename)
# Out:
# WARNING:tensorflow:From <ipython-input-53-7d829c4135ac>:4: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# The predicted class is: Pasillo
#
# WARNING:tensorflow:From <ipython-input-53-7d829c4135ac>:8: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
# Albazo 		 :  0.00618882663547992706298828125000
# Alza 		 :  0.00551735376939177513122558593750
# Capishca 		 :  0.01099091675132513046264648437500
# Danzante 		 :  0.01667597144842147827148437500000
# Pasacalle 		 :  0.01843697577714920043945312500000
# Pasillo 		 :  0.89201587438583374023437500000000
# SanJuanito 		 :  0.00701656518504023551940917968750
# Tonada 		 :  0.00294312182813882827758789062500
# Yumbo 		 :  0.04021449014544486999511718750000
